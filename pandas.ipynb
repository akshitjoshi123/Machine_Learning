# %%
import pandas as pd
import matplotlib.pyplot as plt

mydataset = {
  'Name': ["Akshit", "Palak", "Rajat"],
  'Age': [26, 22, 30]
}

mydata = pd.DataFrame(mydataset)
print(mydata)

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)
print(myvar)


df = pd.read_csv('data.csv', encoding='unicode_escape')

df.plot()

plt.show()
# Out:
#      Name  Age
# 0  Akshit   26
# 1   Palak   22
# 2   Rajat   30
# x    1
# y    7
# z    2
# dtype: int64
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

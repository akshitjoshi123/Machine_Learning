# %%
#Line chart Name to Income
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


df = pd.read_csv('data_matplot.csv', encoding='unicode_escape')
print(df)

X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])

plt.rcParams["figure.autolayout"] = True
plt.plot(X, Y, marker="o")

plt.ylabel("Income")
plt.xlabel("Name")

plt.show()
# Out:
#   Name  Age  Gender       City  Income
# 0    A   23    MALE     MUMBAI  120000
# 1    B   43    MALE      DELHI  230000
# 2    C   21  FEMALE    KOLKATA   80000
# 3    D   65    MALE      DELHI  140000
# 4    E   12  FEMALE  AHMEDABAD  130000
# 5    F   34  FEMALE     MUMBAI   90000
# 6    G   81    MALE    CHENNAI  200000
# 7    H    8  FEMALE       PUNE  150000
# 8    I   45  FEMALE      DELHI   56000
# 9    J   29    MALE  AHMEDABAD  100000

# %%
#bar chart Name to Age

df = pd.read_csv('data_matplot.csv', encoding='unicode_escape')
print(data)

  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])

plt.bar(X,Y, color = 'g')

plt.ylabel("Age")
plt.xlabel("Name")

plt.show()
# Out:
#   Name  Age  Gender       City  Income
# 0    A   23    MALE     MUMBAI  120000
# 1    B   43    MALE      DELHI  230000
# 2    C   21  FEMALE    KOLKATA   80000
# 3    D   65    MALE      DELHI  140000
# 4    E   12  FEMALE  AHMEDABAD  130000
# 5    F   34  FEMALE     MUMBAI   90000
# 6    G   81    MALE    CHENNAI  200000
# 7    H    8  FEMALE       PUNE  150000
# 8    I   45  FEMALE      DELHI   56000
# 9    J   29    MALE  AHMEDABAD  100000

# %%
#scatter chart name to age
df = pd.read_csv('data_matplot.csv', encoding='unicode_escape')
print(data)

  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])

plt.scatter(X,Y, color = 'b')

plt.ylabel("Age")
plt.xlabel("Name")

plt.show()
# Out:
#   Name  Age  Gender       City  Income
# 0    A   23    MALE     MUMBAI  120000
# 1    B   43    MALE      DELHI  230000
# 2    C   21  FEMALE    KOLKATA   80000
# 3    D   65    MALE      DELHI  140000
# 4    E   12  FEMALE  AHMEDABAD  130000
# 5    F   34  FEMALE     MUMBAI   90000
# 6    G   81    MALE    CHENNAI  200000
# 7    H    8  FEMALE       PUNE  150000
# 8    I   45  FEMALE      DELHI   56000
# 9    J   29    MALE  AHMEDABAD  100000

# %%
#pie chart of income
df = pd.read_csv('data_matplot.csv', encoding='unicode_escape')
print(data)

  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 4])


plt.pie(Y,labels = X,autopct = '%.2f%%')
plt.title('Income', fontsize = 20)
plt.show()
# Out:
#   Name  Age  Gender       City  Income
# 0    A   23    MALE     MUMBAI  120000
# 1    B   43    MALE      DELHI  230000
# 2    C   21  FEMALE    KOLKATA   80000
# 3    D   65    MALE      DELHI  140000
# 4    E   12  FEMALE  AHMEDABAD  130000
# 5    F   34  FEMALE     MUMBAI   90000
# 6    G   81    MALE    CHENNAI  200000
# 7    H    8  FEMALE       PUNE  150000
# 8    I   45  FEMALE      DELHI   56000
# 9    J   29    MALE  AHMEDABAD  100000
